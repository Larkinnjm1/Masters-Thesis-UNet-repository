# %%
import os 
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import glob
import matplotlib.pyplot as plt
from collections import Counter

# %%
# !pip install ipdb
# Out:
# Requirement already satisfied: ipdb in c:\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from ipdb) (41.2.0)
# Requirement already satisfied: ipython>=5.1.0; python_version >= "3.4" in c:\anaconda3\lib\site-packages (from ipdb) (7.4.0)
# Requirement already satisfied: traitlets>=4.2 in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (4.3.2)
# Requirement already satisfied: pygments in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (2.3.1)
# Requirement already satisfied: backcall in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (2.0.9)
# Requirement already satisfied: colorama; sys_platform == "win32" in \\nsq024ps\p8\aczd087\appdata\python\python37\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.4.1)
# Requirement already satisfied: jedi>=0.10 in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.13.3)
# Requirement already satisfied: pickleshare in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.7.5)
# Requirement already satisfied: decorator in c:\anaconda3\lib\site-packages (from ipython>=5.1.0; python_version >= "3.4"->ipdb) (4.4.0)
# Requirement already satisfied: six in \\nsq024ps\p8\aczd087\appdata\python\python37\site-packages (from traitlets>=4.2->ipython>=5.1.0; python_version >= "3.4"->ipdb) (1.12.0)
# Requirement already satisfied: ipython-genutils in c:\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.2.0)
# Requirement already satisfied: wcwidth in c:\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in c:\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.1.0; python_version >= "3.4"->ipdb) (0.3.4)

# %% [markdown]
# # Import History Data for analysis

# %%
cd ../../../data/
# Out:
# /home/ec2-user/SageMaker/data

# %%
final_list=[]
for root,subdir,files in os.walk(os.getcwd()):
    if len(files)>0:
        
        file_list=glob.glob(root+'/*history*')
        final_list=final_list+file_list
#Sorted to ensure history part 2,3 etc are synced together 
final_list=sorted(final_list)

# %%
final_list
# Out:
# ['/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_3_lr_0.0003_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_3_lr_0.001_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_3_lr_0.01_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_3_lr_0.1_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_7_lr_0.0003_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_7_lr_0.001_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_7_lr_0.01_time_2019-10-22_history',
#  '/home/ec2-user/SageMaker/data/cat_cross_entropy_wghted/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_cat_ce_loss_cls_wght_trn_samp_sz_250_btch_sz_7_lr_0.1_time_2019-10-22_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_3_lr_0.0003_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_3_lr_0.001_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_3_lr_0.01_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_3_lr_0.01_time_2019-10-20_history_pt2',
#  '/home/ec2-user/SageMaker/data/dice_wghted/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_3_lr_0.1_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_7_lr_0.0003_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_7_lr_0.001_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_7_lr_0.01_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/dice_wghted/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_dice_wght_trn_samp_sz_250_btch_sz_7_lr_0.1_time_2019-10-21_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.0003_time_2019-10-22_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.0003_time_2019-10-26_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.001_time_2019-10-22_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.001_time_2019-10-26_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.01_time_2019-10-22_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.01_time_2019-10-26_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_3_lr_0.1_time_2019-10-27_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.0003_time_2019-10-23_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.0003_time_2019-10-23_time_2019-10-27_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.001_time_2019-10-23_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.001_time_2019-10-23_time_2019-10-27_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.01_time_2019-10-23_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.01_time_2019-10-23_time_2019-10-27_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_bckgrnd_in_loss/btch_sz_7/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.1_time_2019-10-23_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_no_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_cls_idx_no_bkgrnd_trn_samp_sz_250_btch_sz_3_lr_0.0003_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_no_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_cls_idx_no_bkgrnd_trn_samp_sz_250_btch_sz_3_lr_0.001_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_no_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_cls_idx_no_bkgrnd_trn_samp_sz_250_btch_sz_3_lr_0.001_time_2019-10-20_history_pt2',
#  '/home/ec2-user/SageMaker/data/focal_loss_no_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_cls_idx_no_bkgrnd_trn_samp_sz_250_btch_sz_3_lr_0.01_time_2019-10-20_history',
#  '/home/ec2-user/SageMaker/data/focal_loss_no_bckgrnd_in_loss/btch_sz_3/t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_cls_idx_no_bkgrnd_trn_samp_sz_250_btch_sz_3_lr_0.1_time_2019-10-20_history']

# %%
cd F:\Results\Unet\250 strd\history_info\history_files
# Out:
# F:\Results\Unet\250 strd\history_info\history_files

# %%
pickle_dictionary=[]
add_info=[('learn_rate',['0.0003','0.001','0.01','0.1']),
          ('samp_sz',['250']),('btch_sz',['3','7']),
          ('loss_type',['dice','focal','cat'])]

for file in final_list:
    
    if os.path.getsize(file) > 0:
        #print('file found:',file)
        with open(file, "rb") as f:
            unpickler = pickle.Unpickler(f)
            file_dict = unpickler.load()
        #Acquiring file information based on keys in add info from file string.  
        file_dict,split_vals=get_file_info(file,add_info)
            
        #finding if additional sequence values present
        seq_lst=[x for x in split_vals if x in ['pt2','pt3','pt4']]
        
        if len(seq_lst)>0:
            print('appended_values')
            
            #due to sorting of list if pt 2 is found it is found directly after the initial file hence this matching approach
            pickle_dictionary[len(pickle_dictionary)-1],tmp_chk=FullMergeDict(pickle_dictionary[len(pickle_dictionary)-1], 
                                                                              file_dict)
        else:
            #ipdb.set_trace()
            pickle_dictionary.append(file_dict)
    else:
        print('no values in data:',file)


    
    #print(file_dict['btch_sz'])
    #print(file_dict['learn_rate'])
    #print(file_dict['samp_sz'])
    #print(file_dict['loss'])
# Out:
# appended_values
# appended_values
# appended_values
# appended_values
# appended_values
# appended_values
# appended_values
# appended_values

# %%
file
# Out:
# 'F:\\Results\\Unet\\250 strd\\history_info\\history_files\\focal_loss_bckgrnd_in_loss\\btch_sz_7\\t1dual_inphase_all_orgs_grey_lvl_256_optm_adam_loss_focal_loss_all_cls_idx_trn_samp_sz_250_btch_sz_7_lr_0.1_time_2019-10-23_history'

# %%
def get_file_info(file,add_info):
    """The purpose of this method is to pull file information from the file name presnet in the string"""
    split_vals=file.split('_')
    split_vals.sort()
    #Iterate through additional information of set of tuples on file strings for analysis
    for param_k,param_v in add_info:

        file_dict[param_k]=[x for x in param_v if x in split_vals][0]
    return file_dict,split_vals

# %%
def FullMergeDict(D1, D2):
    """The purpose of this method is to merge two dictoinaries irrespective of  variable types"""
    
    for key, value in D1.items():
        #ipdb.set_trace()
        if key in D2:
            if type(value) is dict:
                FullMergeDict(D1[key], D2[key])  
            else:
                if type(value) in (int, float, str):    
                    D1[key] = value
                if type(D2[key]) is list:
                    D1[key].extend(D2[key])
                #else:
                 #   D1[key].append(D2[key])
    for key, value in D2.items():
        
        if key not in D1:
            D1[key] = value
    
    return (D1,D2)

# %% [markdown]
# # Plot different loss function methods

# %% [markdown]
# ## Plotting training and validation data for Categorical cross entropy data

# %%
loss_type_1='cat'

# %% [markdown]
# ### Training data

# %%
loss_type=loss_type_1
fig,axes=plt.subplots(1,2,figsize=(30,20))
leg_nms=[]
for info in pickle_dictionary:
    if info['loss_type']==loss_type and info['learn_rate']!='0.01':
        print(info['loss_type'])
        #tmp dictionary values
        iou_info_val=[info['iou_score']]#,info
        loss_info_val=[info['loss']]#,info

        #print(val_iou)
        str_nm='_'.join([info['learn_rate'],info['btch_sz'],info['loss_type']])
        leg_nms.append(str_nm)

        [axes[0].plot(np.arange(len(i)),i,alpha=0.5) for i in iou_info_val]
        [axes[1].plot(np.arange(len(i)),i,alpha=0.5) for i in loss_info_val]
    
axes[0].set_ylabel('IOU SCORE',fontsize=20)
axes[1].set_ylabel('LOSS',fontsize=20)
[axes_val.set_xlabel('No of Epochs',fontsize=20) for axes_val in axes]
[axes_val.tick_params(axis='both', which='major', labelsize=16) for axes_val in axes]

plt.legend(leg_nms)

plt.show()
# Out:
# cat
# cat
# cat
# cat
# cat
# cat

# %% [markdown]
# ### Validation data

# %%
loss_type=loss_type_1
fig,axes=plt.subplots(1,2,figsize=(30,20))
leg_nms=[]
for info in pickle_dictionary:
    if info['loss_type']==loss_type and info['learn_rate']!='0.01':
        print(info['loss_type'])
        #tmp dictionary values
        iou_info_val=[info['val_f1-score']]#,info['iou_score']
        loss_info_val=[info['val_loss']]#,info['loss']

        #print(val_iou)
        str_nm='_'.join([info['learn_rate'],info['btch_sz'],info['loss_type']])
        leg_nms.append(str_nm)

        [axes[0].plot(np.arange(len(i)),i,alpha=0.5) for i in iou_info_val]
        [axes[1].plot(np.arange(len(i)),i,alpha=0.5) for i in loss_info_val]
    
axes[0].set_ylabel('IOU SCORE',fontsize=20)
axes[1].set_ylabel('LOSS',fontsize=20)
[axes_val.set_xlabel('No of Epochs',fontsize=20) for axes_val in axes]
[axes_val.tick_params(axis='both', which='major', labelsize=16) for axes_val in axes]

plt.legend(leg_nms)

plt.show()
# Out:
# cat
# cat
# cat
# cat
# cat
# cat

# %% [markdown]
# ## Plotting training and validation data for dice weighted entropy data

# %%
loss_type_1='dice'

# %% [markdown]
# ### Training data

# %%
loss_type=loss_type_1
fig,axes=plt.subplots(1,2,figsize=(30,20))
leg_nms=[]
for info in pickle_dictionary:
    if info['loss_type']==loss_type and info['learn_rate']!='0.01':
        print(info['loss_type'])
        #tmp dictionary values
        iou_info_val=[info['iou_score']]#,info
        loss_info_val=[info['loss']]#,info

        #print(val_iou)
        str_nm='_'.join([info['learn_rate'],info['btch_sz'],info['loss_type']])
        leg_nms.append(str_nm)

        [axes[0].plot(np.arange(len(i)),i,alpha=0.5) for i in iou_info_val]
        [axes[1].plot(np.arange(len(i)),i,alpha=0.5) for i in loss_info_val]
    
axes[0].set_ylabel('IOU SCORE',fontsize=20)
axes[1].set_ylabel('LOSS',fontsize=20)
[axes_val.set_xlabel('No of Epochs',fontsize=20) for axes_val in axes]
[axes_val.tick_params(axis='both', which='major', labelsize=16) for axes_val in axes]

plt.legend(leg_nms)

plt.show()
# Out:
# dice
# dice
# dice
# dice
# dice
# dice

# %% [markdown]
# ### Validation data

# %%
loss_type=loss_type_1
fig,axes=plt.subplots(1,2,figsize=(30,20))
leg_nms=[]
for info in pickle_dictionary:
    if info['loss_type']==loss_type and info['learn_rate']!='0.01':
        print(info['loss_type'])
        #tmp dictionary values
        iou_info_val=[info['val_f1-score']]#,info['iou_score']
        loss_info_val=[info['val_loss']]#,info['loss']

        #print(val_iou)
        str_nm='_'.join([info['learn_rate'],info['btch_sz'],info['loss_type']])
        leg_nms.append(str_nm)

        [axes[0].plot(np.arange(len(i)),i,alpha=0.5) for i in iou_info_val]
        [axes[1].plot(np.arange(len(i)),i,alpha=0.5) for i in loss_info_val]
    
axes[0].set_ylabel('Dice SCORE',fontsize=20)
axes[1].set_ylabel('LOSS',fontsize=20)
[axes_val.set_xlabel('No of Epochs',fontsize=20) for axes_val in axes]
[axes_val.tick_params(axis='both', which='major', labelsize=16) for axes_val in axes]

plt.legend(leg_nms)

plt.show()
# Out:
# dice
# dice
# dice
# dice
# dice
# dice

# %% [markdown]
# ## Plotting training and validation data for dice weighted entropy data

# %%
loss_type_1='focal'

# %% [markdown]
# ### Training data

# %%
loss_type=loss_type_1
fig,axes=plt.subplots(1,2,figsize=(30,20))
leg_nms=[]
for info in pickle_dictionary:
    if info['loss_type']==loss_type:# and info['learn_rate']!='0.01'
        print(info['loss_type'])
        #tmp dictionary values
        iou_info_val=[info['iou_score']]#,info
        loss_info_val=[info['loss']]#,info

        #print(val_iou)
        str_nm='_'.join([info['learn_rate'],info['btch_sz'],info['loss_type']])
        leg_nms.append(str_nm)

        [axes[0].plot(np.arange(len(i)),i,alpha=0.5) for i in iou_info_val]
        [axes[1].plot(np.arange(len(i)),i,alpha=0.5) for i in loss_info_val]
    
axes[0].set_ylabel('IOU SCORE',fontsize=20)
axes[1].set_ylabel('LOSS',fontsize=20)
[axes_val.set_xlabel('No of Epochs',fontsize=20) for axes_val in axes]
[axes_val.tick_params(axis='both', which='major', labelsize=16) for axes_val in axes]

plt.legend(leg_nms)

plt.show()
# Out:
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal

# %% [markdown]
# ### Validation data

# %%
loss_type=loss_type_1
fig,axes=plt.subplots(1,2,figsize=(30,20))
leg_nms=[]
for info in pickle_dictionary:
    if info['loss_type']==loss_type:#and info['learn_rate']!='0.01'
        print(info['loss_type'])
        #tmp dictionary values
        iou_info_val=[info['val_f1-score']]#,info['iou_score']
        loss_info_val=[info['val_loss']]#,info['loss']

        #print(val_iou)
        str_nm='_'.join([info['learn_rate'],info['btch_sz'],info['loss_type']])
        leg_nms.append(str_nm)

        [axes[0].plot(np.arange(len(i)),i,alpha=0.5) for i in iou_info_val]
        [axes[1].plot(np.arange(len(i)),i,alpha=0.5) for i in loss_info_val]
    
axes[0].set_ylabel('IOU SCORE',fontsize=20)
axes[1].set_ylabel('LOSS',fontsize=20)
[axes_val.set_xlabel('No of Epochs',fontsize=20) for axes_val in axes]
[axes_val.tick_params(axis='both', which='major', labelsize=16) for axes_val in axes]

plt.legend(leg_nms)

plt.show()
# Out:
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
# focal
